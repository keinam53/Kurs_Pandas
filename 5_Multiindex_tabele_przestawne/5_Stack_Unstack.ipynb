# %% [markdown]
# **Metody stack() i unstack()**

# %%
import pandas as pd
import numpy as np

# %%
incidents = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/Canadian Railway Crossing Incidents.csv')
incidents.set_index(['Region', 'EventType'], inplace=True)
incidents.sort_index(inplace=True)
incidents.head(10)
# Out:
#                                    Public automated  Public passive  Private  \
# Region           EventType
# Alberta          Accidents                        3               7        2
#                  Fatalities                       0               0        0
#                  Serious injuries                 0               1        2
# British Columbia Accidents                        4               1        0
#                  Fatalities                       0               0        0
#                  Serious injuries                 3               0        0
# Manitoba         Accidents                        1               3        0
#                  Fatalities                       0               1        0
#                  Serious injuries                 0               0        0
# New Brunswick    Accidents                        0               0        0
#
#                                    Farm
# Region           EventType
# ...

# %% [markdown]
# Metoda stack bierze wewnętrzny poziom kolumn i przepisuje go do wierszy

# %%
incidents.stack().head()
# Out:
# Region   EventType
# Alberta  Accidents   Public automated    3
#                      Public passive      7
#                      Private             2
#                      Farm                0
#          Fatalities  Public automated    0
# dtype: int64

# %% [markdown]
# Zapisanie do data frame

# %%
incidents.stack().to_frame().head()
# Out:
#                                      0
# Region  EventType
# Alberta Accidents  Public automated  3
#                    Public passive    7
#                    Private           2
#                    Farm              0
#         Fatalities Public automated  0

# %%
stack_incidents = incidents.stack().to_frame()

# %%
stack_incidents.head()
# Out:
#                                      0
# Region  EventType
# Alberta Accidents  Public automated  3
#                    Public passive    7
#                    Private           2
#                    Farm              0
#         Fatalities Public automated  0

# %% [markdown]
# Metoda unstack() działa odwrotnie

# %%
stack_incidents.unstack().head()
# Out:
#                                                  0
#                                   Public automated Public passive Private Farm
# Region           EventType
# Alberta          Accidents                       3              7       2    0
#                  Fatalities                      0              0       0    0
#                  Serious injuries                0              1       2    0
# British Columbia Accidents                       4              1       0    0
#                  Fatalities                      0              0       0    0

# %%
stack_incidents.unstack().unstack().head()
# Out:
#                                 0                                             \
#                  Public automated                             Public passive
# EventType               Accidents Fatalities Serious injuries      Accidents
# Region
# Alberta                         3          0                0              7
# British Columbia                4          0                3              1
# Manitoba                        1          0                0              3
# New Brunswick                   0          0                0              0
# Newfoundland                    0          0                0              0
#
#                                                                    \
#                                                Private
# EventType        Fatalities Serious injuries Accidents Fatalities
# Region
# Alberta                   0                1         2          0
# British Columbia          0                0         0          0
# ...

# %% [markdown]
# Domyślnie level=-1 ale można wpisać inny albo słownie nazwę

# %%
stack_incidents.unstack(0).head()
# Out:
#                                   0                                          \
# Region                      Alberta British Columbia Manitoba New Brunswick
# EventType
# Accidents  Public automated       3                4        1             0
#            Public passive         7                1        3             0
#            Private                2                0        0             0
#            Farm                   0                0        2             0
# Fatalities Public automated       0                0        0             0
#
#                                                                             \
# Region                      Newfoundland Northwest Territories Nova Scotia
# EventType
# Accidents  Public automated            0                     0           1
#            Public passive              0                     0           0
#            Private                     0                     0           0
# ...

# %%
stack_incidents.unstack(level='Region').head()
# Out:
#                                   0                                          \
# Region                      Alberta British Columbia Manitoba New Brunswick
# EventType
# Accidents  Public automated       3                4        1             0
#            Public passive         7                1        3             0
#            Private                2                0        0             0
#            Farm                   0                0        2             0
# Fatalities Public automated       0                0        0             0
#
#                                                                             \
# Region                      Newfoundland Northwest Territories Nova Scotia
# EventType
# Accidents  Public automated            0                     0           1
#            Public passive              0                     0           0
#            Private                     0                     0           0
# ...

# %% [markdown]
# Można więcej niż jedną kolumnę

# %%
stack_incidents.unstack(level=['Region', 'EventType']).head()
# Out:
#                          0                                               \
# Region             Alberta                             British Columbia
# EventType        Accidents Fatalities Serious injuries        Accidents
# Public automated         3          0                0                4
# Public passive           7          0                1                1
# Private                  2          0                2                0
# Farm                     0          0                0                0
#
#                                                                    \
# Region                                        Manitoba
# EventType        Fatalities Serious injuries Accidents Fatalities
# Public automated          0                3         1          0
# Public passive            0                0         3          1
# Private                   0                0         0          0
# Farm                      0                0         2          0
#
# ...

# %% [markdown]
# Wyszukiwanie

# %%
stack_incidents.head()
# Out:
#                                      0
# Region  EventType
# Alberta Accidents  Public automated  3
#                    Public passive    7
#                    Private           2
#                    Farm              0
#         Fatalities Public automated  0

# %%
stack_incidents.loc[('Alberta', 'Accidents', 'Private'), 0]
# Out:
# 2
