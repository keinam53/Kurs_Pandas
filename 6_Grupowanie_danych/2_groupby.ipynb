# %% [markdown]
# **Metoda groupby**

# %%
import pandas as pd
import numpy as np

# %%
products = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/WA_Sales_Products_2012-14.csv')
products.head()
# Out:
#   Retailer country Order method type  Retailer type       Product line  \
# 0    United States               Fax  Outdoors Shop  Camping Equipment
# 1    United States               Fax  Outdoors Shop  Camping Equipment
# 2    United States               Fax  Outdoors Shop  Camping Equipment
# 3    United States               Fax  Outdoors Shop  Camping Equipment
# 4    United States               Fax  Outdoors Shop  Camping Equipment
#
#     Product type                    Product  Year  Quarter    Revenue  \
# 0   Cooking Gear  TrailChef Deluxe Cook Set  2012  Q1 2012   59628.66
# 1   Cooking Gear     TrailChef Double Flame  2012  Q1 2012   35950.32
# 2          Tents                  Star Dome  2012  Q1 2012   89940.48
# 3          Tents               Star Gazer 2  2012  Q1 2012  165883.41
# 4  Sleeping Bags            Hibernator Lite  2012  Q1 2012  119822.20
#
#    Quantity  Gross margin
# 0       489      0.347548
# 1       252      0.474274
# 2       147      0.352772
# ...

# %% [markdown]
# Grupowanie po nazwie miast za pomocą metody groupby()

# %%
groups = products.groupby(by='Retailer country')

# %%
type(groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
len(groups)
# Out:
# 21

# %%
groups.size()
# Out:
# Retailer country
# Australia         3665
# Austria           3862
# Belgium           3710
# Brazil            3288
# Canada            5923
# China             3652
# Denmark           2358
# Finland           3409
# France            5779
# Germany           5397
# Italy             4018
# Japan             5359
# Korea             3399
# Mexico            3845
# Netherlands       4199
# Singapore         3443
# Spain             3557
# Sweden            2925
# Switzerland       4103
# United Kingdom    5102
# United States     7482
# dtype: int64

# %% [markdown]
# Wyciągnięcie pierwszego wiersza z każdej grupy

# %%
groups.first().head()
# Out:
#                  Order method type  Retailer type          Product line  \
# Retailer country
# Australia                Telephone      Golf Shop  Personal Accessories
# Austria                  Telephone      Golf Shop  Personal Accessories
# Belgium                        Web      Golf Shop  Personal Accessories
# Brazil                         Web      Golf Shop  Personal Accessories
# Canada                         Fax  Outdoors Shop  Personal Accessories
#
#                  Product type               Product  Year  Quarter   Revenue  \
# Retailer country
# Australia             Watches  Mountain Man Digital  2012  Q1 2012   2161.34
# Austria               Watches   Mountain Man Analog  2012  Q1 2012   6562.30
# Belgium               Watches  Mountain Man Digital  2012  Q1 2012   2324.46
# Brazil                Watches                 Venue  2012  Q1 2012  15987.00
# Canada                Watches                 Venue  2012  Q1 2012  12045.00
#
# ...

# %%
products[products['Retailer country'] == 'Australia'].head(1)
# Out:
#      Retailer country Order method type Retailer type          Product line  \
# 3735        Australia         Telephone     Golf Shop  Personal Accessories
#
#      Product type               Product  Year  Quarter  Revenue  Quantity  \
# 3735      Watches  Mountain Man Digital  2012  Q1 2012  2161.34        53
#
#       Gross margin
# 3735      0.509564

# %%
products[products['Retailer country'] == 'Canada'].head(1)
# Out:
#     Retailer country Order method type  Retailer type          Product line  \
# 864           Canada               Fax  Outdoors Shop  Personal Accessories
#
#     Product type Product  Year  Quarter  Revenue  Quantity  Gross margin
# 864      Watches   Venue  2012  Q1 2012  12045.0       165       0.41863

# %% [markdown]
# Wyciągnięcie ostatniego wiersza z każdej grupy

# %%
groups.last().head()
# Out:
#                  Order method type     Retailer type          Product line  \
# Retailer country
# Australia              Sales visit  Department Store        Golf Equipment
# Austria                        Web      Sports Store        Golf Equipment
# Belgium                        Web      Sports Store  Personal Accessories
# Brazil                         Web      Sports Store        Golf Equipment
# Canada                         Web      Sports Store        Golf Equipment
#
#                       Product type            Product  Year  Quarter  \
# Retailer country
# Australia                  Putters  Blue Steel Putter  2014  Q3 2014
# Austria           Golf Accessories  Course Pro Gloves  2014  Q3 2014
# Belgium                 Navigation        Astro Pilot  2014  Q3 2014
# Brazil            Golf Accessories  Course Pro Gloves  2014  Q3 2014
# Canada            Golf Accessories  Course Pro Gloves  2014  Q3 2014
#
#                    Revenue  Quantity  Gross margin
# ...

# %%
groups.groups
# Out:
# {'Australia': [3735, 3736, 3737, 3738, 3739, 3740, 3741, 3742, 3743, 3744, 3745, 3746, 3747, 3748, 3749, 3750, 3751, 3752, 3753, 3754, 3755, 3756, 3757, 3758, 3759, 3760, 3761, 3762, 3763, 3764, 3765, 3766, 3767, 3768, 3769, 3770, 3771, 3772, 3773, 3774, 3775, 3776, 3777, 3778, 3779, 3780, 3781, 3782, 3783, 3784, 3785, 3786, 3787, 3788, 3789, 3790, 3791, 3792, 3793, 3794, 3795, 3796, 3797, 3798, 3799, 3800, 3801, 3802, 3803, 3804, 3805, 3806, 3807, 3808, 3809, 3810, 3811, 3812, 3813, 3814, 3815, 3816, 3817, 3818, 3819, 3820, 3821, 3822, 3823, 3824, 3825, 3826, 3827, 3828, 3829, 3830, 3831, 3832, 3833, 3834, ...], 'Austria': [7588, 7589, 7590, 7591, 7592, 7593, 7594, 7595, 7596, 7597, 7598, 7599, 7600, 7601, 7602, 7603, 7604, 7605, 7606, 7607, 7608, 7609, 7610, 7611, 7612, 7613, 7614, 7615, 7616, 7617, 7618, 7619, 7620, 7621, 7622, 7623, 7624, 7625, 7626, 7627, 7628, 7629, 7630, 7631, 7632, 7633, 7634, 7635, 7636, 7637, 7638, 7639, 7640, 7641, 7642, 7643, 7644, 7645, 7646, 7647, 7648,
# ...

# %% [markdown]
# Wyciągnięcie tylko Belgii

# %%
products.loc[groups.groups['Belgium']].head()
# Out:
#      Retailer country Order method type Retailer type          Product line  \
# 7270          Belgium               Web     Golf Shop  Personal Accessories
# 7271          Belgium               Web     Golf Shop  Personal Accessories
# 7272          Belgium               Web     Golf Shop  Personal Accessories
# 7273          Belgium               Web     Golf Shop  Personal Accessories
# 7274          Belgium               Web     Golf Shop  Personal Accessories
#
#      Product type               Product  Year  Quarter   Revenue  Quantity  \
# 7270      Watches  Mountain Man Digital  2012  Q1 2012   2324.46        57
# 7271      Watches   Mountain Man Deluxe  2012  Q1 2012   5267.96        68
# 7272      Watches              Infinity  2012  Q1 2012  22483.00        96
# 7273      Watches                    TX  2012  Q1 2012  16100.00        87
# 7274      Eyewear             Polar Sun  2012  Q1 2012   2682.52        44
#
#       Gross margin
# 7270      0.509564
# ...

# %% [markdown]
# Wyciągnięcie tylko Belgii z obiektu groups za pomocą metody get_group

# %%
groups.get_group('Belgium').head()
# Out:
#      Retailer country Order method type Retailer type          Product line  \
# 7270          Belgium               Web     Golf Shop  Personal Accessories
# 7271          Belgium               Web     Golf Shop  Personal Accessories
# 7272          Belgium               Web     Golf Shop  Personal Accessories
# 7273          Belgium               Web     Golf Shop  Personal Accessories
# 7274          Belgium               Web     Golf Shop  Personal Accessories
#
#      Product type               Product  Year  Quarter   Revenue  Quantity  \
# 7270      Watches  Mountain Man Digital  2012  Q1 2012   2324.46        57
# 7271      Watches   Mountain Man Deluxe  2012  Q1 2012   5267.96        68
# 7272      Watches              Infinity  2012  Q1 2012  22483.00        96
# 7273      Watches                    TX  2012  Q1 2012  16100.00        87
# 7274      Eyewear             Polar Sun  2012  Q1 2012   2682.52        44
#
#       Gross margin
# 7270      0.509564
# ...
