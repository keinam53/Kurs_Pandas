# %% [markdown]
# **Parametry metody plot**

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
bar = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/weather_barcelona.csv',
                 index_col='Date')
rom = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/weather_rome.csv',
                 index_col='Date')
ams = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/weather_amsterdam.csv',
                 index_col='Date')

# %%
bar.head(3)
# Out:
#             TempMax  TempMin  Rain  AvgTempMax  AvgTempMin
# Date
# 2018-01-01       17       11     0          13           7
# 2018-01-02       19        8     0          13           7
# 2018-01-03       23       11     0          13           7

# %% [markdown]
# Stworzenie nowego DF zawierającego temp max z 3 miast

# %%
temp_max = pd.DataFrame(index=bar.index)
temp_max['Barcelona'] = bar['TempMax']
temp_max['Rome'] = rom['TempMax']
temp_max['Amsterdam'] = ams['TempMax']
temp_max.head()
# Out:
#             Barcelona  Rome  Amsterdam
# Date
# 2018-01-01         17    14          8
# 2018-01-02         19    13          9
# 2018-01-03         23    14         11
# 2018-01-04         24    16         11
# 2018-01-05         20    17          8

# %% [markdown]
# Rysowanie wykresu

# %%
temp_max.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# figsize - powiększenie wykresu

# %%
temp_max.plot(figsize=(15, 4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# subplots - generuje osobny wykres dla każdej serii danych

# %%
temp_max.plot(figsize=(15, 5), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>], dtype=object)

# %% [markdown]
# use_index=False - wpisanie wartości indeksu na oś X wykresu

# %%
temp_max.plot(figsize=(15, 5), use_index=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# title - tytuł wykresu

# %%
temp_max.plot(figsize=(15, 4), title='Maksymalne temperatury w miastach')
# Out:
# <AxesSubplot:title={'center':'Maksymalne temperatury w miastach'}, xlabel='Date'>

# %% [markdown]
# legend=False - wyłączenie legendy

# %%
temp_max.plot(figsize=(15, 4), legend=False)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# logy=True - zmiana skali osi Y na logarytmiczną

# %%
temp_max.plot(figsize=(15, 4), logy=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# xticks - wartości wyświetlane pod wykresem, rot - kąt

# %%
temp_max[:14].plot(figsize=(15, 4), xticks=(range(14)), rot=45)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# table=True - tabela pod wykresem

# %%
temp_max[:7].plot(figsize=(15, 4), table=True)
# Out:
# <AxesSubplot:xlabel='Date'>
