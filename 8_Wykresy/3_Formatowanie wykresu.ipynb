# %% [markdown]
# **Formatowanie wykresu**

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
import seaborn as sns

# %%
bar = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/weather_barcelona.csv',
                 index_col='Date')
rom = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/weather_rome.csv',
                 index_col='Date')
ams = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/weather_amsterdam.csv',
                 index_col='Date')

# %%
temp_max = pd.DataFrame(index=bar.index)
temp_max['Barcelona'] = bar['TempMax']
temp_max['Rome'] = rom['TempMax']
temp_max['Amsterdam'] = ams['TempMax']
temp_max.head()
# Out:
#             Barcelona  Rome  Amsterdam
# Date
# 2018-01-01         17    14          8
# 2018-01-02         19    13          9
# 2018-01-03         23    14         11
# 2018-01-04         24    16         11
# 2018-01-05         20    17          8

# %%
bar.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# color - zmiana koloru wykresu

# %%
bar.plot(color=['b', 'g', 'r', 'm', 'k'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# colormap - zestaw kolorów. Wszystkie zestawy opisane są w nocie katalogowej matplotlib

# %%
bar.plot(colormap='gnuplot')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Wszystkie style matplotlib

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('Solarize_Light2')
bar.plot(grid=False)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Można konfigurować gotowe style, nie wszystkie działają
