# %% [markdown]
# **Rysowanie wykresów metodą plot**

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
bar = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/weather_barcelona.csv',
                 index_col='Date')

# %%
rom = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/weather_rome.csv',
                 index_col='Date')

# %%
ams = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/weather_amsterdam.csv',
                 index_col='Date')

# %%
bar.head(3)
# Out:
#             TempMax  TempMin  Rain  AvgTempMax  AvgTempMin
# Date
# 2018-01-01       17       11     0          13           7
# 2018-01-02       19        8     0          13           7
# 2018-01-03       23       11     0          13           7

# %% [markdown]
# Narysowanie wykresu ze wszystkich danych tabeli

# %%
bar.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Narysowanie wykresu dla jednej serii danych tabeli

# %%
bar['TempMax'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Używając argumentu metody plot

# %%
bar.plot(y='TempMax')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Dwie serie

# %%
bar[['TempMax', 'TempMin']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Używając argumentu metody plot

# %%
bar.plot(y=['TempMax', 'TempMin'])
# Out:
# <AxesSubplot:xlabel='Date'>
