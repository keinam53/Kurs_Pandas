# %% [markdown]
# **Dodawanie i usuwanie kolumn**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
frame = pd.read_csv("C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/Mcdonalds.csv",
                   usecols=["Item", "Category", "Calories", "TotalFat", "Sugars", "Protein", "Cholesterol"])
frame.head()
# Out:
#     Category                              Item  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin       300      13.0
# 1  Breakfast                 Egg White Delight       250       8.0
# 2  Breakfast                  Sausage McMuffin       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites       400      23.0
#
#    Cholesterol  Sugars  Protein
# 0          260       3       17
# 1           25       3       18
# 2           45       2       14
# 3          285       2       21
# 4           50       2       21

# %%
frame.TotalFat.head()
# Out:
# 0    13.0
# 1     8.0
# 2    23.0
# 3    28.0
# 4    23.0
# Name: TotalFat, dtype: float64

# %%
frame["TotalFat"].head()
# Out:
# 0    13.0
# 1     8.0
# 2    23.0
# 3    28.0
# 4    23.0
# Name: TotalFat, dtype: float64

# %% [markdown]
# Dodawanie kolumn:
#
# Dodawana kolumna będzie na końcu tabeli

# %%
frame["NewCol"] = 0
frame.head()
# Out:
#     Category                              Item  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin       300      13.0
# 1  Breakfast                 Egg White Delight       250       8.0
# 2  Breakfast                  Sausage McMuffin       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites       400      23.0
#
#    Cholesterol  Sugars  Protein  NewCol
# 0          260       3       17       0
# 1           25       3       18       0
# 2           45       2       14       0
# 3          285       2       21       0
# 4           50       2       21       0

# %%
frame["SugarAndProtein"] = frame.Sugars + frame.Protein
frame.head()
# Out:
#     Category                              Item  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin       300      13.0
# 1  Breakfast                 Egg White Delight       250       8.0
# 2  Breakfast                  Sausage McMuffin       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites       400      23.0
#
#    Cholesterol  Sugars  Protein  NewCol  SugarAndProtein
# 0          260       3       17       0               20
# 1           25       3       18       0               21
# 2           45       2       14       0               16
# 3          285       2       21       0               23
# 4           50       2       21       0               23

# %% [markdown]
# Dodawanie kolumny w określonym miejscu:

# %%
frame.insert(loc=2, column="SFP", value=frame.Sugars + frame.TotalFat + frame.Protein)
frame.head()
# Out:
#     Category                              Item   SFP  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin  33.0       300      13.0
# 1  Breakfast                 Egg White Delight  29.0       250       8.0
# 2  Breakfast                  Sausage McMuffin  39.0       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg  51.0       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  46.0       400      23.0
#
#    Cholesterol  Sugars  Protein  NewCol  SugarAndProtein
# 0          260       3       17       0               20
# 1           25       3       18       0               21
# 2           45       2       14       0               16
# 3          285       2       21       0               23
# 4           50       2       21       0               23

# %% [markdown]
# Usuwanie kolumn:

# %%
del frame["NewCol"]
frame.head()
# Out:
#     Category                              Item   SFP  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin  33.0       300      13.0
# 1  Breakfast                 Egg White Delight  29.0       250       8.0
# 2  Breakfast                  Sausage McMuffin  39.0       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg  51.0       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  46.0       400      23.0
#
#    Cholesterol  Sugars  Protein  SugarAndProtein
# 0          260       3       17               20
# 1           25       3       18               21
# 2           45       2       14               16
# 3          285       2       21               23
# 4           50       2       21               23

# %%
frame = frame.drop(columns="SugarAndProtein")

# %%
frame.head()
# Out:
#     Category                              Item   SFP  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin  33.0       300      13.0
# 1  Breakfast                 Egg White Delight  29.0       250       8.0
# 2  Breakfast                  Sausage McMuffin  39.0       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg  51.0       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  46.0       400      23.0
#
#    Cholesterol  Sugars  Protein
# 0          260       3       17
# 1           25       3       18
# 2           45       2       14
# 3          285       2       21
# 4           50       2       21
