# %%
import pandas as pd
import numpy as np

# %%
animals = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/sleep_time.csv',
                     index_col='ID').fillna(value=0)
animals.head()
# Out:
#                           name       genus   vore         order  conservation  \
# ID
# 1                      Cheetah    Acinonyx  carni     Carnivora            lc
# 2                   Owl monkey       Aotus   omni      Primates             0
# 3              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 5                          Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ID
# 1          12.1        0.0     0.000000   11.9  0.00000   50.000
# 2          17.0        1.8     0.000000    7.0  0.01550    0.480
# 3          14.4        2.4     0.000000    9.6  0.00000    1.350
# 4          14.9        2.3     0.133333    9.1  0.00029    0.019
# 5           4.0        0.7     0.666667   20.0  0.42300  600.000

# %%
is_herbi = animals['vore'] == 'herbi'
herbi = animals.where(is_herbi)
herbi.head()
# Out:
#                name       genus   vore         order  conservation  \
# ID
# 1               NaN         NaN    NaN           NaN           NaN
# 2               NaN         NaN    NaN           NaN           NaN
# 3   Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4               NaN         NaN    NaN           NaN           NaN
# 5               Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 1           NaN        NaN          NaN    NaN      NaN     NaN
# 2           NaN        NaN          NaN    NaN      NaN     NaN
# 3          14.4        2.4     0.000000    9.6    0.000    1.35
# 4           NaN        NaN          NaN    NaN      NaN     NaN
# 5           4.0        0.7     0.666667   20.0    0.423  600.00

# %%
len(herbi)
# Out:
# 83

# %%
len(herbi.dropna())
# Out:
# 32

# %%
is_carni = animals['vore'] == 'carni'
carni = animals.where(is_carni)
carni.head()
# Out:
#        name     genus   vore      order conservation  sleep_total  sleep_rem  \
# ID
# 1   Cheetah  Acinonyx  carni  Carnivora           lc         12.1        0.0
# 2       NaN       NaN    NaN        NaN          NaN          NaN        NaN
# 3       NaN       NaN    NaN        NaN          NaN          NaN        NaN
# 4       NaN       NaN    NaN        NaN          NaN          NaN        NaN
# 5       NaN       NaN    NaN        NaN          NaN          NaN        NaN
#
#     sleep_cycle  awake  brainwt  bodywt
# ID
# 1           0.0   11.9      0.0    50.0
# 2           NaN    NaN      NaN     NaN
# 3           NaN    NaN      NaN     NaN
# 4           NaN    NaN      NaN     NaN
# 5           NaN    NaN      NaN     NaN

# %%
len(carni)
# Out:
# 83

# %%
len(carni.dropna(how='all'))
# Out:
# 19

# %%
is_omni = animals['vore'] == 'omni'
omni = animals.where(is_omni)
omni.head()
# Out:
#                           name    genus  vore         order conservation  \
# ID
# 1                          NaN      NaN   NaN           NaN          NaN
# 2                   Owl monkey    Aotus  omni      Primates            0
# 3                          NaN      NaN   NaN           NaN          NaN
# 4   Greater short-tailed shrew  Blarina  omni  Soricomorpha           lc
# 5                          NaN      NaN   NaN           NaN          NaN
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 1           NaN        NaN          NaN    NaN      NaN     NaN
# 2          17.0        1.8     0.000000    7.0  0.01550   0.480
# 3           NaN        NaN          NaN    NaN      NaN     NaN
# 4          14.9        2.3     0.133333    9.1  0.00029   0.019
# 5           NaN        NaN          NaN    NaN      NaN     NaN

# %%
len(omni)
# Out:
# 83

# %%
len(omni.dropna(how='all'))
# Out:
# 20

# %%
print(f'Roślinożerne: {herbi["sleep_total"].mean()}')
print(f'Mięsożerne: {carni["sleep_total"].mean()}')
print(f'Wszystkożerne: {omni["sleep_total"].mean()}')
# Out:
# Roślinożerne: 9.509375
# Mięsożerne: 10.378947368421054
# Wszystkożerne: 10.924999999999999

# %%
animals.query('sleep_total > 14').head()
# Out:
#                           name       genus   vore         order conservation  \
# ID
# 2                   Owl monkey       Aotus   omni      Primates            0
# 3              Mountain beaver  Aplodontia  herbi      Rodentia           nt
# 4   Greater short-tailed shrew     Blarina   omni  Soricomorpha           lc
# 6             Three-toed sloth    Bradypus  herbi        Pilosa            0
# 18        Long-nosed armadillo     Dasypus  carni     Cingulata           lc
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 2          17.0        1.8     0.000000    7.0  0.01550   0.480
# 3          14.4        2.4     0.000000    9.6  0.00000   1.350
# 4          14.9        2.3     0.133333    9.1  0.00029   0.019
# 6          14.4        2.2     0.766667    9.6  0.00000   3.850
# 18         17.4        3.1     0.383333    6.6  0.01080   3.500

# %%
animals.query('sleep_total > 14 and vore == "herbi"')
# Out:
#                               name         genus   vore     order  \
# ID
# 3                  Mountain beaver    Aplodontia  herbi  Rodentia
# 6                 Three-toed sloth      Bradypus  herbi    Pilosa
# 27       Western american chipmunk      Eutamias  herbi  Rodentia
# 39                Mongolian gerbil      Meriones  herbi  Rodentia
# 40                  Golden hamster  Mesocricetus  herbi  Rodentia
# 44            Round-tailed muskrat      Neofiber  herbi  Rodentia
# 70          Arctic ground squirrel  Spermophilus  herbi  Rodentia
# 72  Golden-mantled ground squirrel  Spermophilus  herbi  Rodentia
# 76       Eastern american chipmunk        Tamias  herbi  Rodentia
#
#    conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 3            nt         14.4        2.4     0.000000    9.6   0.0000   1.350
# 6             0         14.4        2.2     0.766667    9.6   0.0000   3.850
# ...

# %%
animals.query('sleep_total > 14 and vore == "herbi" and bodywt > 1')
# Out:
#                 name       genus   vore     order conservation  sleep_total  \
# ID
# 3    Mountain beaver  Aplodontia  herbi  Rodentia           nt         14.4
# 6   Three-toed sloth    Bradypus  herbi    Pilosa            0         14.4
#
#     sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 3         2.4     0.000000    9.6      0.0    1.35
# 6         2.2     0.766667    9.6      0.0    3.85
