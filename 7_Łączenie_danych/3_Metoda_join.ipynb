# %% [markdown]
# **Metoda join()**

# %%
import pandas as pd
import numpy as np

# %%
prod_1 = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/northwind/products.csv',
                    usecols=['ProductID', 'ProductName'], index_col='ProductID')
prod_2 = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/northwind/products.csv',
                    usecols=['ProductID', 'UnitPrice', 'UnitsInStock'], index_col='ProductID')

# %%
prod_1.head()
# Out:
#                             ProductName
# ProductID
# 1                                  Chai
# 2                                 Chang
# 3                         Aniseed Syrup
# 4          Chef Anton's Cajun Seasoning
# 5                Chef Anton's Gumbo Mix

# %%
prod_2.head()
# Out:
#            UnitPrice  UnitsInStock
# ProductID
# 1              18.00            39
# 2              19.00            17
# 3              10.00            13
# 4              22.00            53
# 5              21.35             0

# %% [markdown]
# Metoda join - połączenie tabel tak, żeby przypisać do tabeli 2 nazwy z tabeli 1. Działa gdy obie tabele mają taki sam indeks

# %%
prod_1.join(prod_2).head()
# Out:
#                             ProductName  UnitPrice  UnitsInStock
# ProductID
# 1                                  Chai      18.00            39
# 2                                 Chang      19.00            17
# 3                         Aniseed Syrup      10.00            13
# 4          Chef Anton's Cajun Seasoning      22.00            53
# 5                Chef Anton's Gumbo Mix      21.35             0

# %%
categories = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/northwind/categories1.csv',
                        usecols=['CategoryID', 'CategoryName', 'Description'])
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %%
products = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/northwind/products.csv',
                      usecols=['ProductID', 'ProductName', 'UnitPrice', 'CategoryID'])
products.head()
# Out:
#    ProductID                   ProductName  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
categories.set_index('CategoryID', inplace=True)
categories.head()
# Out:
#               CategoryName              Description
# CategoryID
# 1                Beverages              Soft drinks
# 2               Condiments  Sweet and savory sauces
# 3              Confections                 Desserts
# 4           Dairy Products                  Cheeses
# 5           Grains/Cereals                   Breads

# %%
products.join(other=categories, on='CategoryID').head()
# Out:
#    ProductID                   ProductName  CategoryID  UnitPrice  \
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35
#
#   CategoryName              Description
# 0    Beverages              Soft drinks
# 1    Beverages              Soft drinks
# 2   Condiments  Sweet and savory sauces
# 3   Condiments  Sweet and savory sauces
# 4   Condiments  Sweet and savory sauces

# %% [markdown]
# on wyznacza po której kolumnie z drugiej tabeli ma być łączenie
