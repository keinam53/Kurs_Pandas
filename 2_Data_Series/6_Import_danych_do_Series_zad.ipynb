# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
pd.read_csv("C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/StackOverflowDeveloperSurvey.csv")
# Out:
#        Respondent                                       Professional  \
# 0               1                                            Student
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# ...           ...                                                ...
# 51387       51388                             Professional developer
# 51388       51389                                            Student
# 51389       51390                             Professional developer
# 51390       51391                             Professional developer
# 51391       51392  Professional non-developer who sometimes write...
#
#                     ProgramHobby         Country      University  \
# 0                      Yes, both   United States              No
# ...

# %%
education = pd.read_csv("C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/StackOverflowDeveloperSurvey.csv",
                       usecols=["FormalEducation"])
print(education)
# Out:
#                                          FormalEducation
# 0                                       Secondary school
# 1      Some college/university study without earning ...
# 2                                      Bachelor's degree
# 3                                        Doctoral degree
# 4                                        Master's degree
# ...                                                  ...
# 51387                                  Bachelor's degree
# 51388                                    Master's degree
# 51389  Some college/university study without earning ...
# 51390                                  Bachelor's degree
# 51391                                  Bachelor's degree
#
# [51392 rows x 1 columns]

# %%
type(education)
# Out:
# pandas.core.frame.DataFrame

# %%
education.head()
# Out:
#                                      FormalEducation
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree

# %%
education = pd.read_csv("C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/StackOverflowDeveloperSurvey.csv",
                       usecols=["FormalEducation"], squeeze=True)
print(education)
# Out:
# 0                                         Secondary school
# 1        Some college/university study without earning ...
# 2                                        Bachelor's degree
# 3                                          Doctoral degree
# 4                                          Master's degree
#                                ...
# 51387                                    Bachelor's degree
# 51388                                      Master's degree
# 51389    Some college/university study without earning ...
# 51390                                    Bachelor's degree
# 51391                                    Bachelor's degree
# Name: FormalEducation, Length: 51392, dtype: object

# %%
type(education)
# Out:
# pandas.core.series.Series

# %%
education.tail(10)
# Out:
# 51382                                      Master's degree
# 51383               I never completed any formal education
# 51384                                    Bachelor's degree
# 51385                                      Master's degree
# 51386    Some college/university study without earning ...
# 51387                                    Bachelor's degree
# 51388                                      Master's degree
# 51389    Some college/university study without earning ...
# 51390                                    Bachelor's degree
# 51391                                    Bachelor's degree
# Name: FormalEducation, dtype: object

# %%
all_info = pd.read_csv("C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/StackOverflowDeveloperSurvey.csv")

# %%
country = all_info["Country"]

# %%
country.head()
# Out:
# 0     United States
# 1    United Kingdom
# 2    United Kingdom
# 3     United States
# 4       Switzerland
# Name: Country, dtype: object

# %%
filter_only_usa = country == "United States"

# %%
filter_only_usa.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Country, dtype: bool

# %%
education.where(filter_only_usa).dropna().head(10)
# Out:
# 0              Secondary school
# 3               Doctoral degree
# 6               Master's degree
# 10            Bachelor's degree
# 15    Primary/elementary school
# 17            Bachelor's degree
# 18            Bachelor's degree
# 25              Master's degree
# 27            Bachelor's degree
# 29            Bachelor's degree
# Name: FormalEducation, dtype: object
