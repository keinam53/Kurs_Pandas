# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
salary = pd.read_csv("C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/StackOverflowDeveloperSurvey.csv",
                 usecols=["Salary"], squeeze=True).dropna()
print(salary)
# Out:
# 2        113750.000000
# 14       100000.000000
# 17       130000.000000
# 18        82500.000000
# 22       100764.000000
#              ...
# 51371     74193.548387
# 51378    107526.881720
# 51382     32258.064516
# 51387     58000.000000
# 51390     40000.000000
# Name: Salary, Length: 12891, dtype: float64

# %%
salary.head()
# Out:
# 2     113750.0
# 14    100000.0
# 17    130000.0
# 18     82500.0
# 22    100764.0
# Name: Salary, dtype: float64

# %% [markdown]
# Osoby, które podały swoje wynagrodzenie:

# %%
len(salary)
# Out:
# 12891

# %%
print(min(salary))
print(max(salary))
# Out:
# 0.0
# 197000.0

# %%
list(salary.head())
# Out:
# [113750.0, 100000.0, 130000.0, 82500.0, 100764.0]

# %%
dict(salary.head())
# Out:
# {2: 113750.0, 14: 100000.0, 17: 130000.0, 18: 82500.0, 22: 100764.0}

# %%
list_salary_sorted = sorted(salary, reverse=True)
print(list_salary_sorted)
# Out:
# [197000.0, 195000.0, 195000.0, 195000.0, 195000.0, 195000.0, 194000.0, 193750.0, 193000.0, 192000.0, 192000.0, 190000.0, 190000.0, 190000.0, 190000.0, 190000.0, 190000.0, 190000.0, 188000.0, 187500.0, 187200.0, 187000.0, 185000.0, 185000.0, 185000.0, 185000.0, 185000.0, 185000.0, 185000.0, 184000.0, 182000.0, 181818.181818182, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 180000.0, 178000.0, 178000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 175000.0, 174242.424242424, 174000.0, 174000.0, 173716.668114306, 173300.0, 173000.0, 173000.0, 173000.0, 172300.0, 172043.010752688, 172000.0, 172000.0, 172000.0, 172000.0, 172000.0, 171000.0, 170940.170940171, 170000.
# ...

# %%
list_salary_sorted[:5]
# Out:
# [197000.0, 195000.0, 195000.0, 195000.0, 195000.0]

# %%
salary.head()
# Out:
# 2     113750.0
# 14    100000.0
# 17    130000.0
# 18     82500.0
# 22    100764.0
# Name: Salary, dtype: float64

# %%
salary.name = "Salary of a person"

# %%
salary.head()
# Out:
# 2     113750.0
# 14    100000.0
# 17    130000.0
# 18     82500.0
# 22    100764.0
# Name: Salary of a person, dtype: float64
