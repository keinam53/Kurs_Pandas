# %% [markdown]
# **Export danych**

# %%
import pandas as pd
import numpy as np

# %%
df_blood = pd.DataFrame({'Group'     : ['0', '0', 'A', 'A', 'B', 'B', 'AB', 'AB'],
                        'Rh'         : ['+', '-', '+', '-', '+', '-', '+', '-'],
                        'Population' : [31,6,32,6,15,2,7,1]})
df_blood
# Out:
#   Group Rh  Population
# 0     0  +          31
# 1     0  -           6
# 2     A  +          32
# 3     A  -           6
# 4     B  +          15
# 5     B  -           2
# 6    AB  +           7
# 7    AB  -           1

# %% [markdown]
# Export danych do pliku csv

# %%
df_blood.to_csv('blood.csv')

# %%
df_blood_proc = df_blood['Population'] / 100

# %%
df_blood_proc
# Out:
# 0    0.31
# 1    0.06
# 2    0.32
# 3    0.06
# 4    0.15
# 5    0.02
# 6    0.07
# 7    0.01
# Name: Population, dtype: float64

# %%
df_blood['Population'] = df_blood_proc
df_blood
# Out:
#   Group Rh  Population
# 0     0  +        0.31
# 1     0  -        0.06
# 2     A  +        0.32
# 3     A  -        0.06
# 4     B  +        0.15
# 5     B  -        0.02
# 6    AB  +        0.07
# 7    AB  -        0.01

# %% [markdown]
# Ponowny zapis do csv index=False - nie zapisze się indeks

# %%
df_blood.to_csv('blood.csv', index=False)

# %% [markdown]
# Eksport tylko wybranych kolumn

# %%
df_blood.to_csv('blood.csv', index=False, columns=['Group', 'Rh'])

# %%
pd.read_csv('blood.csv')
# Out:
#   Group Rh
# 0     0  +
# 1     0  -
# 2     A  +
# 3     A  -
# 4     B  +
# 5     B  -
# 6    AB  +
# 7    AB  -

# %% [markdown]
# Jeśli przy zapisie dodajemy sep=... to taki sam musi być przy doczycie

# %%
df_blood.to_csv('blood.csv', index=False, columns=['Group', 'Rh'], sep=';')

# %%
pd.read_csv('blood.csv', sep=';')
# Out:
#   Group Rh
# 0     0  +
# 1     0  -
# 2     A  +
# 3     A  -
# 4     B  +
# 5     B  -
# 6    AB  +
# 7    AB  -

# %% [markdown]
# mod='a' - dopisanie do istniejącego pliku ,header=False - nie wypisze się kolejny nagłówek

# %%
df_blood.to_csv('blood.csv', index=False, columns=['Group', 'Rh'], sep=':', mode='a', header=False)

# %%
pd.read_csv('blood.csv', sep=';')
# Out:
#    Group   Rh
# 0      0    +
# 1      0    -
# 2      A    +
# 3      A    -
# 4      B    +
# 5      B    -
# 6     AB    +
# 7     AB    -
# 8    0:+  NaN
# 9    0:-  NaN
# 10   A:+  NaN
# 11   A:-  NaN
# 12   B:+  NaN
# 13   B:-  NaN
# 14  AB:+  NaN
# 15  AB:-  NaN

# %% [markdown]
# Eksport do pliku json

# %%
df_blood.to_json('blood.json')

# %%
pd.read_json('blood.json')
# Out:
#   Group Rh  Population
# 0     0  +        0.31
# 1     0  -        0.06
# 2     A  +        0.32
# 3     A  -        0.06
# 4     B  +        0.15
# 5     B  -        0.02
# 6    AB  +        0.07
# 7    AB  -        0.01
