# %% [markdown]
# **Dodawanie i usuwanie wierszy w Data Frame**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
frame = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/sleep_time.csv',
                   index_col='ID')
frame.head()
# Out:
#                           name       genus   vore         order  conservation  \
# ID
# 1                      Cheetah    Acinonyx  carni     Carnivora            lc
# 2                   Owl monkey       Aotus   omni      Primates           NaN
# 3              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 5                          Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ID
# 1          12.1        NaN          NaN   11.9      NaN   50.000
# 2          17.0        1.8          NaN    7.0  0.01550    0.480
# 3          14.4        2.4          NaN    9.6      NaN    1.350
# 4          14.9        2.3     0.133333    9.1  0.00029    0.019
# 5           4.0        0.7     0.666667   20.0  0.42300  600.000

# %% [markdown]
# Usuwanie kolumn

# %%
del frame['bodywt']
frame.head()
# Out:
#                           name       genus   vore         order  conservation  \
# ID
# 1                      Cheetah    Acinonyx  carni     Carnivora            lc
# 2                   Owl monkey       Aotus   omni      Primates           NaN
# 3              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 5                          Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt
# ID
# 1          12.1        NaN          NaN   11.9      NaN
# 2          17.0        1.8          NaN    7.0  0.01550
# 3          14.4        2.4          NaN    9.6      NaN
# 4          14.9        2.3     0.133333    9.1  0.00029
# 5           4.0        0.7     0.666667   20.0  0.42300

# %%
frame.drop(axis=1, columns=['awake', 'brainwt'], inplace=True)
frame.head()
# Out:
#                           name       genus   vore         order  conservation  \
# ID
# 1                      Cheetah    Acinonyx  carni     Carnivora            lc
# 2                   Owl monkey       Aotus   omni      Primates           NaN
# 3              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 5                          Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle
# ID
# 1          12.1        NaN          NaN
# 2          17.0        1.8          NaN
# 3          14.4        2.4          NaN
# 4          14.9        2.3     0.133333
# 5           4.0        0.7     0.666667

# %%
frame.drop(axis='columns', columns='sleep_cycle', inplace=True)
frame.head()
# Out:
#                           name       genus   vore         order  conservation  \
# ID
# 1                      Cheetah    Acinonyx  carni     Carnivora            lc
# 2                   Owl monkey       Aotus   omni      Primates           NaN
# 3              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 5                          Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total  sleep_rem
# ID
# 1          12.1        NaN
# 2          17.0        1.8
# 3          14.4        2.4
# 4          14.9        2.3
# 5           4.0        0.7

# %%
frame.drop(columns='sleep_rem', inplace=True)
frame.head()
# Out:
#                           name       genus   vore         order  conservation  \
# ID
# 1                      Cheetah    Acinonyx  carni     Carnivora            lc
# 2                   Owl monkey       Aotus   omni      Primates           NaN
# 3              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 5                          Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total
# ID
# 1          12.1
# 2          17.0
# 3          14.4
# 4          14.9
# 5           4.0

# %% [markdown]
# Usuwanie wierszy

# %%
frame.drop(axis=0, labels=[1, 2], inplace=True)
frame.head()
# Out:
#                           name        genus   vore         order  \
# ID
# 3              Mountain beaver   Aplodontia  herbi      Rodentia
# 4   Greater short-tailed shrew      Blarina   omni  Soricomorpha
# 5                          Cow          Bos  herbi  Artiodactyla
# 6             Three-toed sloth     Bradypus  herbi        Pilosa
# 7            Northern fur seal  Callorhinus  carni     Carnivora
#
#     conservation  sleep_total
# ID
# 3             nt         14.4
# 4             lc         14.9
# 5   domesticated          4.0
# 6            NaN         14.4
# 7             vu          8.7

# %%
frame.drop(axis='rows', labels=3, inplace=True)
frame.head()
# Out:
#                           name        genus   vore         order  \
# ID
# 4   Greater short-tailed shrew      Blarina   omni  Soricomorpha
# 5                          Cow          Bos  herbi  Artiodactyla
# 6             Three-toed sloth     Bradypus  herbi        Pilosa
# 7            Northern fur seal  Callorhinus  carni     Carnivora
# 8                 Vesper mouse      Calomys    NaN      Rodentia
#
#     conservation  sleep_total
# ID
# 4             lc         14.9
# 5   domesticated          4.0
# 6            NaN         14.4
# 7             vu          8.7
# 8            NaN          7.0

# %%
frame.drop(labels=4, inplace=True)
frame.head()
# Out:
#                  name        genus   vore         order  conservation  \
# ID
# 5                 Cow          Bos  herbi  Artiodactyla  domesticated
# 6    Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 7   Northern fur seal  Callorhinus  carni     Carnivora            vu
# 8        Vesper mouse      Calomys    NaN      Rodentia           NaN
# 9                 Dog        Canis  carni     Carnivora  domesticated
#
#     sleep_total
# ID
# 5           4.0
# 6          14.4
# 7           8.7
# 8           7.0
# 9          10.1

# %%
frame.drop(5, inplace=True)
frame.head()
# Out:
#                  name        genus   vore         order  conservation  \
# ID
# 6    Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 7   Northern fur seal  Callorhinus  carni     Carnivora            vu
# 8        Vesper mouse      Calomys    NaN      Rodentia           NaN
# 9                 Dog        Canis  carni     Carnivora  domesticated
# 10           Roe deer    Capreolus  herbi  Artiodactyla            lc
#
#     sleep_total
# ID
# 6          14.4
# 7           8.7
# 8           7.0
# 9          10.1
# 10          3.0

# %% [markdown]
# Dodawanie wierszy

# %%
frame.append({'name': 'Panda', 'genus': np.NaN, 'vore': np.NaN, 'order': np.NaN, 'conservation': np.NaN,
              'sleep_total': 10}, ignore_index=True).tail()
# Out:
#                     name     genus   vore      order conservation  sleep_total
# 74  Bottle-nosed dolphin  Tursiops  carni    Cetacea          NaN          5.2
# 75                 Genet   Genetta  carni  Carnivora          NaN          6.3
# 76            Arctic fox    Vulpes  carni  Carnivora          NaN         12.5
# 77               Red fox    Vulpes  carni  Carnivora          NaN          9.8
# 78                 Panda       NaN    NaN        NaN          NaN         10.0

# %% [markdown]
# Dodawanie z użyciem innego data frame zapisanego w zmiennej

# %%
subset = frame[0:5]
subset
# Out:
#                  name        genus   vore         order  conservation  \
# ID
# 6    Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 7   Northern fur seal  Callorhinus  carni     Carnivora            vu
# 8        Vesper mouse      Calomys    NaN      Rodentia           NaN
# 9                 Dog        Canis  carni     Carnivora  domesticated
# 10           Roe deer    Capreolus  herbi  Artiodactyla            lc
#
#     sleep_total
# ID
# 6          14.4
# 7           8.7
# 8           7.0
# 9          10.1
# 10          3.0

# %%
frame = frame.append(subset)
frame.tail()
# Out:
#                  name        genus   vore         order  conservation  \
# ID
# 6    Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 7   Northern fur seal  Callorhinus  carni     Carnivora            vu
# 8        Vesper mouse      Calomys    NaN      Rodentia           NaN
# 9                 Dog        Canis  carni     Carnivora  domesticated
# 10           Roe deer    Capreolus  herbi  Artiodactyla            lc
#
#     sleep_total
# ID
# 6          14.4
# 7           8.7
# 8           7.0
# 9          10.1
# 10          3.0
