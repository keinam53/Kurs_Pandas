# %% [markdown]
# **Modyfikacja danych w data frame**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
frame = pd.read_csv('C:/Users/Mariusz Baran/Data_Science_kurs/Data_science_pliki/course-files/insurance.csv')
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25      197      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      20
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25      284      63

# %% [markdown]
# Modyfikacja jednej komórki:

# %%
frame.loc[2, 'Claims']
# Out:
# 20

# %%
frame.loc[2, 'Claims'] = 19
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25      197      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      19
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25      284      63

# %%
frame.loc[2, 'Claims'] = frame.loc[2, 'Claims'] + 1
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25      197      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      20
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25      284      63

# %%
frame.loc[2, 'Claims'] += 1
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25      197      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      21
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25      284      63

# %% [markdown]
# Modyfikacja większej ilości komórek:

# %%
younger_25 = frame['Age'] == '<25'
frame.where(younger_25).dropna().head()
# Out:
#       ID  District   Group  Age  Holders  Claims
# 0    1.0       1.0     <1l  <25    197.0    38.0
# 4    5.0       1.0  1-1.5l  <25    284.0    63.0
# 8    9.0       1.0  1.5-2l  <25    133.0    19.0
# 12  13.0       1.0     >2l  <25     24.0     4.0
# 16  17.0       2.0     <1l  <25     85.0    22.0

# %%
frame[younger_25].head()
# Out:
#     ID  District   Group  Age  Holders  Claims
# 0    1         1     <1l  <25      197      38
# 4    5         1  1-1.5l  <25      284      63
# 8    9         1  1.5-2l  <25      133      19
# 12  13         1     >2l  <25       24       4
# 16  17         2     <1l  <25       85      22

# %%
frame.loc[younger_25, 'Holders'].head()
# Out:
# 0     197
# 4     284
# 8     133
# 12     24
# 16     85
# Name: Holders, dtype: int64

# %%
(frame.loc[younger_25, 'Holders'] + 100).head()
# Out:
# 0     297
# 4     384
# 8     233
# 12    124
# 16    185
# Name: Holders, dtype: int64

# %%
frame.loc[younger_25, 'Holders'] = frame.loc[younger_25, 'Holders'] + 100
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25      297      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      21
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25      384      63

# %% [markdown]
# Uproszczony zapis:

# %%
frame.loc[younger_25, 'Holders'] += 1000
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25     1297      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      21
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25     1384      63

# %%
frame.loc[younger_25, 'Holders'] = frame['Holders'] + 1000
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25     2397      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      21
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25     2484      63
